# %%
import pandas as pd
path= r"C:\EveriTools\Workspace\Code\DemandForeCast\Data\processed\game_attr_cleaned.csv"

# %%
x1=pd.read_csv(path)
x1
# Out:
#       theme_sk theme_nk source_system_cd source_company_cd  \
# 0            1     0000        ATLASSIAN             EVERI
# 1            2    10000        ATLASSIAN             EVERI
# 2            3    10003        ATLASSIAN             EVERI
# 3            4    10005        ATLASSIAN             EVERI
# 4            5    10006        ATLASSIAN             EVERI
# ...        ...      ...              ...               ...
# 4389      4390     8175        ATLASSIAN             EVERI
# 4390      4391     8176        ATLASSIAN             EVERI
# 4391      4392     8177        ATLASSIAN             EVERI
# 4392      4393     8178        ATLASSIAN             EVERI
# 4393      4394     8179        ATLASSIAN             EVERI
#
#                              theme_name                theme_name_friendly  \
# 0     InitialRelease_Template_GameTitle  InitialRelease_Template_GameTitle
# 1               Tourney Now Star Struck            Tourney Now Star Struck
# ...

# %%
x['theme_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='theme_name'>
