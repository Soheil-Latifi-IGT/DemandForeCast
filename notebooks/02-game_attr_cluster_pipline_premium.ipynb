# %%
eilerspath='development_042_silver_sandbox.demand_forecast.eilers_landbased_performance_clean_sl'
mappingpath='development_042_silver_sandbox.demand_forecast.eilers_to_gdna_mapping_silver'
atrpath='development_042_silver_sandbox.demand_forecast.igt_everi_attributes_silver'
destpath='development_042_silver_sandbox.demand_forecast.game_attributes_class_3_premium_clustering_gold' # change to core c3

# %%
display(eilers_df.select("own_status", "parent_own_status","game_classification").distinct())

# %%
eilers_df = spark.read.table(eilerspath)
mapping_df = spark.read.table(mappingpath)
atr_df = spark.read.table(atrpath)

display(eilers_df.limit(5))
display(mapping_df.limit(5))
display(atr_df.limit(5))

# %%
# Filter eilers to Class3 + Cre + owned (any game with at least 1 matching row is included)
eilers_filtered = (
    eilers_df
    .filter(
        (F.col("parent_own_status") != "Core") &
        (F.col("own_status") == "leased")
    )
)

# Aggregate per game: min release date, keep classification/status (constant after filter)
eilers_agg_df = (
    eilers_filtered
    .groupBy("game_name", "game_classification", "parent_own_status")
    .agg(F.min("game_release_date").alias("min_game_release_date"))
)

result_df = (
    joined_df.join(
        eilers_agg_df,
        joined_df.correction == eilers_agg_df.game_name,
        "inner"
    )
    .drop("min_game_release_date", "ep_normalized_for_matching", "score_margin", "second_best_score", "confidence_band")
)

display(result_df)

# %%
result_df.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable(destpath)
